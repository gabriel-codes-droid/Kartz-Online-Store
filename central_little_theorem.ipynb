# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriel-codes-droid/KARTZ-Art-place/blob/main/central_little_theorem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

num_samples = 10000
sample_size = 50

data = np.random.randint(1, 7, (num_samples, sample_size))
sample_means = np.mean(data, axis=1)

plt.figure(figsize=(10, 6))
plt.hist(sample_means, bins=30, color='skyblue', edgecolor='black', density=True)
plt.title(f'Central Limit Theorem (n={sample_size})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.show()
